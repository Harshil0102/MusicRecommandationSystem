# %%
pip install transformers torch spotipy opencv-python
# Out:
# Requirement already satisfied: transformers in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (4.43.3)
# Requirement already satisfied: torch in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (2.4.0)
# Requirement already satisfied: spotipy in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (2.24.0)
# Requirement already satisfied: opencv-python in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: filelock in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\stoke\appdata\roaming\python\python312\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.5.0)
# Requirement already satisfied: setuptools in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from torch) (70.3.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (5.0.7)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\stoke\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\stoke\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from transformers import pipeline, AutoImageProcessor, AutoModelForImageClassification
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
from PIL import Image
import pandas as pd

# Capture image using cv2
def capture_image():
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Could not open webcam")
        return None

    ret, frame = cap.read()

    if not ret:
        print("Failed to capture image")
        return None

    cap.release()

    image_path = "captured_image.jpg"
    cv2.imwrite(image_path, frame)

    return image_path

# Load the image-based emotion detection model
processor = AutoImageProcessor.from_pretrained("dima806/facial_emotions_image_detection")
model = AutoModelForImageClassification.from_pretrained("dima806/facial_emotions_image_detection")

# Create a pipeline for emotion detection
emotion_classifier = pipeline("image-classification", model=model, feature_extractor=processor)

# Set up Spotify API credentials
client_id = "380a6b3535dc420a905dccf328a0e165"  
client_secret = "b0ca7947448246d28aafc40f49610cf4"  

# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# Define emotion to genre/characteristic mapping
emotion_to_genre = {
    'happy': ['pop', 'dance', 'electropop'],
    'sad': ['acoustic', 'blues', 'soul'],
    'angry': ['rock', 'metal', 'punk'],
    'neutral': ['jazz', 'classical', 'ambient'],
    'fear': ['dark', 'soundtrack', 'experimental'],
    'surprise': ['pop', 'alternative', 'indie'],
    'disgust': ['punk', 'grunge', 'hardcore']
}

# Function to detect emotion from the image
def detect_emotion_from_image(image_path):
    image = Image.open(image_path)
    predictions = emotion_classifier(image)
    detected_emotion = predictions[0]['label'].lower()
    return detected_emotion

# Function to get songs for the detected emotion and display in table format
def get_songs_for_emotion(emotion):
    if emotion in emotion_to_genre:
        genres = emotion_to_genre[emotion]
        genre_query = " ".join([f"genre:{genre}" for genre in genres])
        
        results = sp.search(q=genre_query, type='track', limit=20)
        tracks = results['tracks']['items']
        
        if not tracks:
            return None
        
        # Prepare data for the table
        songs_data = []
        for track in tracks:
            track_id = track['id']
            track_name = track['name']
            artist_name = track['artists'][0]['name']
            album_name = track['album']['name']
            spotify_link = track['external_urls']['spotify']
            
            # Append the track info to the songs_data list
            songs_data.append({
                "Track ID": track_id,
                "Track Name": track_name,
                "Artist": artist_name,
                "Album": album_name,
                "Spotify Link": spotify_link
            })
        
        # Convert the list of dictionaries to a DataFrame
        songs_df = pd.DataFrame(songs_data)
        return songs_df
    else:
        return None

# Main function to capture image, detect emotion, and recommend songs
def main():
    image_path = capture_image()
    
    if image_path:
        detected_emotion = detect_emotion_from_image(image_path)
        print(f"Detected emotion: {detected_emotion}")
        
        recommended_songs_df = get_songs_for_emotion(detected_emotion.lower())
        
        if recommended_songs_df is not None and not recommended_songs_df.empty:
            print("Here are some songs for your mood:")
            print(recommended_songs_df.to_markdown(index=False))
        else:
            print("No recommendations available for this emotion or no emotion detected.")

# Example usage
if __name__ == "__main__":
    main()
# Out:
# Detected emotion: surprise
# Here are some songs for your mood:
# | Track ID               | Track Name                  | Artist                | Album                                                                   | Spotify Link                                          |
# |:-----------------------|:----------------------------|:----------------------|:------------------------------------------------------------------------|:------------------------------------------------------|
# | 6WTFHKrnZpwEBLRS10Ylqs | misses                      | Dominic Fike          | 14 minutes                                                              | https://open.spotify.com/track/6WTFHKrnZpwEBLRS10Ylqs |
